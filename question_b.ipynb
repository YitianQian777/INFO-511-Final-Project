# %%
# research question (b)
# What makes and models are the most popular electric vehicles in the state of Washington?

# %%
import pandas as pd
import matplotlib.pyplot as plt

ev_population_data = pd.read_csv(r"C:\Users\LIMI\Desktop\Foundation of Data Science\Milestone1\Electric_Vehicle_Population_Data.csv")

print(ev_population_data.head())
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  WBY8P4C55K      King  Bothell    WA      98011.0        2019     BMW
# 1  KNDCE3LG1K  Thurston  Olympia    WA      98502.0        2019     KIA
# 2  5YJYGDEE8L      King  Seattle    WA      98125.0        2020   TESLA
# 3  1N4AZ0CP0F  Thurston  Olympia    WA      98506.0        2015  NISSAN
# 4  WA1E2AFY8R      King  Seattle    WA      98119.0        2024    AUDI
#
#      Model                   Electric Vehicle Type  \
# 0       I3  Plug-in Hybrid Electric Vehicle (PHEV)
# 1     NIRO          Battery Electric Vehicle (BEV)
# 2  MODEL Y          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4     Q5 E  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible           126.0
# 1           Clean Alternative Fuel Vehicle Eligible           239.0
# 2           Clean Alternative Fuel Vehicle Eligible           291.0
# 3           Clean Alternative Fuel Vehicle Eligible            84.0
# 4             Not eligible due to low battery range            23.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0        0.0                   1.0       249382416
# 1        0.0                  22.0       102638791
# 2        0.0                  46.0       112603774
# 3        0.0                  22.0       187006893
# 4        0.0                  36.0       271736741
#
#               Vehicle Location                               Electric Utility  \
# 0  POINT (-122.20563 47.76144)  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)
# 1  POINT (-122.92333 47.03779)                         PUGET SOUND ENERGY INC
# 2  POINT (-122.30253 47.72656)   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
# 3  POINT (-122.87741 47.05997)                         PUGET SOUND ENERGY INC
# 4   POINT (-122.3684 47.64586)   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)
#
#    2020 Census Tract
# 0       5.303302e+10
# 1       5.306701e+10
# 2       5.303300e+10
# 3       5.306701e+10
# 4       5.303301e+10

# %%
print(ev_population_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223995 entries, 0 to 223994
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         223995 non-null  object
#  1   County                                             223992 non-null  object
#  2   City                                               223992 non-null  object
#  3   State                                              223995 non-null  object
#  4   Postal Code                                        223992 non-null  float64
#  5   Model Year                                         223995 non-null  int64
#  6   Make                                               223995 non-null  object
#  7   Model                                              223995 non-null  object
#  8   Electric Vehicle Type                              223995 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  223995 non-null  object
#  10  Electric Range                                     223977 non-null  float64
#  11  Base MSRP                                          223977 non-null  float64
#  12  Legislative District                               223521 non-null  float64
#  13  DOL Vehicle ID                                     223995 non-null  int64
#  14  Vehicle Location                                   223985 non-null  object
#  15  Electric Utility                                   223992 non-null  object
#  16  2020 Census Tract                                  223992 non-null  float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 29.1+ MB
# None

# %%
ev_population_data_NA = ev_population_data[ev_population_data.isnull().any(axis = 1)]
ev_population_data_NA.head(10)
# Out:
#        VIN (1-10)     County           City State  Postal Code  Model Year  \
# 709    5YJSA1E42L     Placer      Roseville    CA      95747.0        2020
# 2543   WP1BE2AY0S       King       Bellevue    WA      98005.0        2025
# 7201   WP1BM2AY4R       King       Kirkland    WA      98033.0        2024
# 18664  WP1BN2AY7S       King        Seattle    WA      98112.0        2025
# 23337  WP1BE2AY8S       King        Seattle    WA      98125.0        2025
# 24999  WP1AE2AY0S       King  Mercer Island    WA      98040.0        2025
# 27261  WP1BM2AY1R       King        Seattle    WA      98108.0        2024
# 37358  W1NKM8AB0S       King       Bellevue    WA      98006.0        2025
# 64436  W1NKM8AB9S       King        Seattle    WA      98122.0        2025
# 65629  5YJYGDED0M  San Diego      San Diego    CA      92131.0        2021
#
#                 Make      Model                   Electric Vehicle Type  \
# 709            TESLA    MODEL S          Battery Electric Vehicle (BEV)
# 2543         PORSCHE    CAYENNE  Plug-in Hybrid Electric Vehicle (PHEV)
# 7201         PORSCHE    CAYENNE  Plug-in Hybrid Electric Vehicle (PHEV)
# 18664        PORSCHE    CAYENNE  Plug-in Hybrid Electric Vehicle (PHEV)
# 23337        PORSCHE    CAYENNE  Plug-in Hybrid Electric Vehicle (PHEV)
# 24999        PORSCHE    CAYENNE  Plug-in Hybrid Electric Vehicle (PHEV)
# 27261        PORSCHE    CAYENNE  Plug-in Hybrid Electric Vehicle (PHEV)
# 37358  MERCEDES-BENZ  GLC-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 64436  MERCEDES-BENZ  GLC-CLASS  Plug-in Hybrid Electric Vehicle (PHEV)
# 65629          TESLA    MODEL Y          Battery Electric Vehicle (BEV)
#
#        Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 709              Clean Alternative Fuel Vehicle Eligible           337.0
# 2543             Clean Alternative Fuel Vehicle Eligible             NaN
# 7201             Clean Alternative Fuel Vehicle Eligible             NaN
# 18664            Clean Alternative Fuel Vehicle Eligible             NaN
# 23337            Clean Alternative Fuel Vehicle Eligible             NaN
# 24999            Clean Alternative Fuel Vehicle Eligible             NaN
# 27261            Clean Alternative Fuel Vehicle Eligible             NaN
# 37358            Clean Alternative Fuel Vehicle Eligible             NaN
# 64436            Clean Alternative Fuel Vehicle Eligible             NaN
# 65629  Eligibility unknown as battery range has not b...             0.0
#
#        Base MSRP  Legislative District  DOL Vehicle ID  \
# 709          0.0                   NaN       267663469
# 2543         NaN                  48.0       274102944
# 7201         NaN                  45.0       270889363
# 18664        NaN                  43.0       274203905
# 23337        NaN                  46.0       274122320
# 24999        NaN                  41.0       272915765
# 27261        NaN                  11.0       272220189
# 37358        NaN                  41.0       275628825
# 64436        NaN                  37.0       274080355
# 65629        0.0                   NaN       187492175
#
#                   Vehicle Location  \
# 709    POINT (-121.33747 38.80276)
# 2543    POINT (-122.1718 47.59246)
# 7201    POINT (-122.2066 47.67887)
# 18664  POINT (-122.30207 47.64085)
# 23337  POINT (-122.30253 47.72656)
# 24999  POINT (-122.21238 47.57816)
# 27261  POINT (-122.30346 47.55379)
# 37358  POINT (-122.12096 47.55584)
# 64436  POINT (-122.31009 47.60803)
# 65629  POINT (-117.06451 32.90323)
#
#                                     Electric Utility  2020 Census Tract
# 709            NON WASHINGTON STATE ELECTRIC UTILITY       6.061021e+09
# 2543   PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 7201   PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 18664   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 23337   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303300e+10
# 24999  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 27261   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 37358  PUGET SOUND ENERGY INC||CITY OF TACOMA - (WA)       5.303302e+10
# 64436   CITY OF SEATTLE - (WA)|CITY OF TACOMA - (WA)       5.303301e+10
# 65629          NON WASHINGTON STATE ELECTRIC UTILITY       6.073017e+09

# %%
print(ev_population_data_NA.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 499 entries, 709 to 223979
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   VIN (1-10)                                         499 non-null    object
#  1   County                                             496 non-null    object
#  2   City                                               496 non-null    object
#  3   State                                              499 non-null    object
#  4   Postal Code                                        496 non-null    float64
#  5   Model Year                                         499 non-null    int64
#  6   Make                                               499 non-null    object
#  7   Model                                              499 non-null    object
#  8   Electric Vehicle Type                              499 non-null    object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  499 non-null    object
#  10  Electric Range                                     481 non-null    float64
#  11  Base MSRP                                          481 non-null    float64
#  12  Legislative District                               25 non-null     float64
#  13  DOL Vehicle ID                                     499 non-null    int64
#  14  Vehicle Location                                   489 non-null    object
#  15  Electric Utility                                   496 non-null    object
#  16  2020 Census Tract                                  496 non-null    float64
# dtypes: float64(5), int64(2), object(10)
# memory usage: 70.2+ KB
# None

# %%
# Deal with NA values for ev_population_data
# replace missing values for the variable "Legislative District" with the string value "Missing"
ev_population_data["Legislative District"] = ev_population_data["Legislative District"].fillna("Missing")

# remove all rows that have any missing value for other variables
ev_population_data = ev_population_data.dropna()

print(ev_population_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 223967 entries, 0 to 223994
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         223967 non-null  object
#  1   County                                             223967 non-null  object
#  2   City                                               223967 non-null  object
#  3   State                                              223967 non-null  object
#  4   Postal Code                                        223967 non-null  float64
#  5   Model Year                                         223967 non-null  int64
#  6   Make                                               223967 non-null  object
#  7   Model                                              223967 non-null  object
#  8   Electric Vehicle Type                              223967 non-null  object
#  9   Clean Alternative Fuel Vehicle (CAFV) Eligibility  223967 non-null  object
#  10  Electric Range                                     223967 non-null  float64
#  11  Base MSRP                                          223967 non-null  float64
#  12  Legislative District                               223967 non-null  object
#  13  DOL Vehicle ID                                     223967 non-null  int64
#  14  Vehicle Location                                   223967 non-null  object
#  15  Electric Utility                                   223967 non-null  object
#  16  2020 Census Tract                                  223967 non-null  float64
# dtypes: float64(4), int64(2), object(11)
# memory usage: 30.8+ MB
# None

# %%
# We have to count how many time the electric vehicle make and model appears in the dataset
grouped = ev_population_data.groupby(['Make', 'Model']).size().reset_index(name='Count')

# Top 10 popular make and model appears
grouped_sorted = grouped.sort_values('Count', ascending=False)
print(grouped_sorted.head(10))
# Out:
#            Make           Model  Count
# 141       TESLA         MODEL Y  46582
# 138       TESLA         MODEL 3  34461
# 119      NISSAN            LEAF  13735
# 139       TESLA         MODEL S   7765
# 39    CHEVROLET         BOLT EV   7007
# 140       TESLA         MODEL X   6242
# 55         FORD  MUSTANG MACH-E   4774
# 43    CHEVROLET            VOLT   4720
# 153  VOLKSWAGEN            ID.4   4653
# 79         JEEP        WRANGLER   4291

# %%
# Grouped bar chart 
top10 = grouped_sorted.head(10)

# we use labels = the combination of make and model
labels = top10['Make'] + " " + top10['Model']
plt.figure(figsize=(12, 6))
plt.bar(labels, top10['Count'], color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.xlabel("Make and Model")
plt.ylabel("Number of Electric Vehicles")
plt.title("Top 10 Popular Electric Vehicles in Washington")
bars = plt.bar(labels, top10['Count'], color='skyblue')
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width()/2,  
        height,                           
        f"{int(height)}",                 
        ha='center',                      
        va='bottom'                      
    )
plt.tight_layout()
plt.show()

# %%
# Tree map
import squarify

top10['Label'] = top10['Make'] + "\n" + top10['Model'] + "\n" + top10['Count'].astype(str)
plt.figure(figsize=(12, 8))
squarify.plot(sizes=top10['Count'], label=top10['Label'], alpha=0.8)
plt.title("Top 10 Popular Electric Vehicles in Washington")
plt.axis('off')
plt.show()
# Out:
# C:\Users\LIMI\AppData\Local\Temp\ipykernel_15552\4078458681.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top10['Label'] = top10['Make'] + "\n" + top10['Model'] + "\n" + top10['Count'].astype(str)
